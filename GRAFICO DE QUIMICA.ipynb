# %% [markdown]
# <a href="https://colab.research.google.com/github/Adriangh1/GRAFICO-DE-QUIMICA/blob/main/GRAFICO%20DE%20QUIMICA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Importamos liberias e instalamos drawdata

# %%
# !pip install drawdata

# %%
from drawdata import draw_scatter, draw_histogram, draw_line

# %% [markdown]
# Seguimos importando y dibujamos el grafico en draw_histrogram()

# %%
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-cbece3b2-35e3-453c-b34c-df9f2d2c4ad9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cbece3b2-35e3-453c-b34c-df9f2d2c4ad9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Tras descargar el gráfico, lo subimos y lo ponemos a leer y reconocer tendencias

# %%
grafico1 = pd.read_csv("grafico1.csv")
grafico1
# Out:
#          x         y  z
# 0    0.000  0.030969  a
# 1    0.025  0.132969  a
# 2    0.050  0.276969  a
# 3    0.075  0.490969  a
# 4    0.100  0.672969  a
# ..     ...       ... ..
# 115  0.875  0.110969  c
# 116  0.900  0.090969  c
# 117  0.925  0.070969  c
# 118  0.950  0.052969  c
# 119  0.975  0.036969  c
#
# [120 rows x 3 columns]

# %%
plt.scatter(grafico1["x"],grafico1["y"])

# %% [markdown]
# Grafico en base a puntos

# %%
grafico["x"].mean()
# Out:
# 0.4875

# %%
grafico1["x"].median()
# Out:
# 0.4875

# %%
grafico1["x"].std()
# Out:
# 0.28979491444291217

# %%
grafico1.describe()
# Out:
#                 x           y
# count  120.000000  120.000000
# mean     0.487500    0.167893
# std      0.289795    0.180796
# min      0.000000   -0.001031
# 25%      0.243750    0.000727
# 50%      0.487500    0.131969
# 75%      0.731250    0.255469
# max      0.975000    0.950969

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a035e901-a07a-4512-84a6-8a8728f30bda" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a035e901-a07a-4512-84a6-8a8728f30bda">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Realizamos lo mismo con el segundo gráfico

# %%
grafico2 = pd.read_csv("Grafico 2.csv")
grafico2
# Out:
#          x         y  z
# 0    0.000  0.042465  a
# 1    0.025  0.206465  a
# 2    0.050  0.444465  a
# 3    0.075  0.688465  a
# 4    0.100  0.920465  a
# ..     ...       ... ..
# 115  0.875  0.050465  c
# 116  0.900  0.048465  c
# 117  0.925  0.044465  c
# 118  0.950  0.032465  c
# 119  0.975  0.022465  c
#
# [120 rows x 3 columns]

# %%
plt.scatter(grafico2["x"],grafico2["y"])

# %%
grafico2["x"].mean()
# Out:
# 0.4875

# %%
grafico2["x"].median()
# Out:
# 0.4875

# %%
grafico2["x"].std()
# Out:
# 0.28979491444291217

# %%
grafico2.describe()
# Out:
#                 x           y
# count  120.000000  120.000000
# mean     0.487500    0.121345
# std      0.289795    0.191748
# min      0.000000    0.000000
# 25%      0.243750    0.000000
# 50%      0.487500    0.044465
# 75%      0.731250    0.176965
# max      0.975000    0.988465
